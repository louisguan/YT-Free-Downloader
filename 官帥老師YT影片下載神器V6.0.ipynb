# %%
# 加上 -q (quiet) 可以讓安裝過程的輸出更簡潔
print("⏳ 正在安裝 yt-dlp...")
# !pip install -q yt-dlp
print("✅ yt-dlp 安裝完成！")
# Out:
# ⏳ 正在安裝 yt-dlp...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 44.9 MB/s eta 0:00:00
# ✅ yt-dlp 安裝完成！

# %%
#@title 👇 請在此貼上影片網址並執行
#@markdown 將網址貼入下方的輸入框中，然後點擊播放按鈕。
video_url = "https://www.youtube.com/shorts/V2JE4WRSe8I" #@param {type:"string"}
download_folder = "colab_downloads"

import os

# 確保下載資料夾存在
os.makedirs(download_folder, exist_ok=True)

if video_url:
  print(f"⬇️ 準備下載單一影片: {video_url}")
  print("⚙️ 指令將忽略播放清單，僅下載此網址對應的影片，並合併為最高畫質 MP4。")
  print("-" * 40)

  # --no-playlist: 關鍵參數！如果網址在一個播放清單中，只下載該影片，不下載整個清單。
  # -f "bestvideo+bestaudio": 選擇最好的影像和最好的音訊串流。
  # --merge-output-format mp4: 將影像和音訊合併為 mp4 格式。
  # -P {download_folder}: 指定下載目錄。
  # !yt-dlp --no-playlist -f "bestvideo+bestaudio" --merge-output-format mp4 -P {download_folder} "{video_url}"

  print("-" * 40)
  print("✅ 下載程序執行完畢！")
else:
  print("❌ 錯誤：請務必在上方輸入框中提供影片網址！")
# Out:
# ⬇️ 準備下載單一影片: https://www.youtube.com/shorts/V2JE4WRSe8I
# ⚙️ 指令將忽略播放清單，僅下載此網址對應的影片，並合併為最高畫質 MP4。
# ----------------------------------------
# [youtube] Extracting URL: https://www.youtube.com/shorts/V2JE4WRSe8I
# [youtube] V2JE4WRSe8I: Downloading webpage
# [youtube] V2JE4WRSe8I: Downloading android sdkless player API JSON
# [youtube] V2JE4WRSe8I: Downloading tv client config
# [youtube] V2JE4WRSe8I: Downloading tv player API JSON
# [youtube] V2JE4WRSe8I: Downloading web safari player API JSON
# [youtube] V2JE4WRSe8I: Downloading player c6d7bdc9-main
# WARNING: [youtube] Falling back to generic n function search
#          player = https://www.youtube.com/s/player/c6d7bdc9/player_ias.vflset/en_US/base.js
# WARNING: [youtube] V2JE4WRSe8I: nsig extraction failed: Some formats may be missing
#          n = fIAn9Su6eYdrnsGR ; player = https://www.youtube.com/s/player/c6d7bdc9/player_ias.vflset/en_US/base.js
# ...

# %%
# 列出下載資料夾中的所有檔案
print(f"'{download_folder}' 資料夾中的內容：")
# !ls -lh {download_folder} # 加上 -h 讓檔案大小更容易閱讀
# Out:
# 'colab_downloads' 資料夾中的內容：
# total 19M
# -rw-r--r-- 1 root root 19M Nov  2 01:11 '【MV】沒出息 Useless｜議場版 Parliament Version (cover by 音樂人王搏) [LRN6ouM2ZnE].mp4'
